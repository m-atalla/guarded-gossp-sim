# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
NETWORK_SIZE=500
import const

# %%
# Data for plotting

fig, ax = plt.subplots()
ax.plot([50,150,200, 250], [26,12,60, 70], color='black',linestyle='_')

ax.set(xlabel='Number of iterations', ylabel='Fraction of malicious nodes [%]',
       title=f'A network size of {NETWORK_SIZE}')
ax.grid()
ax.set_xlim([0, 500])
plt.xticks([x for x in range(501) if x % 50 == 0])
ax.set_ylim([0, 100])

plt.show()
